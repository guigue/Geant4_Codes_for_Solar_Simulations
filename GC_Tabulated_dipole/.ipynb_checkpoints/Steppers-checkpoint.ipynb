# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('_nt_target_t1.g4', comment='#', index_col=False, names=('Track','ParentID', 'PDG', 'Ekin', 'x', 'y','z', 'Mx', 'My', 'Mz', 'time', 'w', 'Px', 'Py', 'Pz','Vx', 'Vy', 'Vz', 'VMx', 'VMy', 'VMz', 'VEkin', 'CPName'))
data2 = pd.read_csv('_nt_target_t0.g4', comment='#', index_col=False, names=('Track','ParentID', 'PDG', 'Ekin', 'x', 'y','z', 'Mx', 'My', 'Mz', 'time', 'w', 'Px', 'Py', 'Pz','Vx', 'Vy', 'Vz', 'VMx', 'VMy', 'VMz', 'VEkin', 'CPName'))
data3 = pd.read_csv('proton.g4', comment='#', index_col=False, names=('Track','ParentID', 'PDG', 'Ekin', 'x', 'y','z', 'Mx', 'My', 'Mz', 'time', 'w', 'Px', 'Py', 'Pz','Vx', 'Vy', 'Vz', 'VMx', 'VMy', 'VMz', 'VEkin', 'CPName'))
dataGC = pd.read_csv('protonGC.g4', comment='#', index_col=False, names=('Track','ParentID', 'PDG', 'Ekin', 'x', 'y','z', 'Mx', 'My', 'Mz', 'time', 'w', 'Px', 'Py', 'Pz','Vx', 'Vy', 'Vz', 'VMx', 'VMy', 'VMz', 'VEkin', 'CPName'))
dataGCRK4 = pd.read_csv('protonGCRK4.g4', comment='#', index_col=False, names=('Track','ParentID', 'PDG', 'Ekin', 'x', 'y','z', 'Mx', 'My', 'Mz', 'time', 'w', 'Px', 'Py', 'Pz','Vx', 'Vy', 'Vz', 'VMx', 'VMy', 'VMz', 'VEkin', 'CPName'))
dataGCHEE = pd.read_csv('protonGCHEE.g4', comment='#', index_col=False, names=('Track','ParentID', 'PDG', 'Ekin', 'x', 'y','z', 'Mx', 'My', 'Mz', 'time', 'w', 'Px', 'Py', 'Pz','Vx', 'Vy', 'Vz', 'VMx', 'VMy', 'VMz', 'VEkin', 'CPName'))
dataGCHSR = pd.read_csv('protonGCHSR.g4', comment='#', index_col=False, names=('Track','ParentID', 'PDG', 'Ekin', 'x', 'y','z', 'Mx', 'My', 'Mz', 'time', 'w', 'Px', 'Py', 'Pz','Vx', 'Vy', 'Vz', 'VMx', 'VMy', 'VMz', 'VEkin', 'CPName'))
dataGCNys = pd.read_csv('protonGCNys.g4', comment='#', index_col=False, names=('Track','ParentID', 'PDG', 'Ekin', 'x', 'y','z', 'Mx', 'My', 'Mz', 'time', 'w', 'Px', 'Py', 'Pz','Vx', 'Vy', 'Vz', 'VMx', 'VMy', 'VMz', 'VEkin', 'CPName'))
dataGCDP78 = pd.read_csv('protonDP78.g4', comment='#', index_col=False, names=('Track','ParentID', 'PDG', 'Ekin', 'x', 'y','z', 'Mx', 'My', 'Mz', 'time', 'w', 'Px', 'Py', 'Pz','Vx', 'Vy', 'Vz', 'VMx', 'VMy', 'VMz', 'VEkin', 'CPName'))
dataGCNys2 = pd.read_csv('protonGCNys2.g4', comment='#', index_col=False, names=('Track','ParentID', 'PDG', 'Ekin', 'x', 'y','z', 'Mx', 'My', 'Mz', 'time', 'w', 'Px', 'Py', 'Pz','Vx', 'Vy', 'Vz', 'VMx', 'VMy', 'VMz', 'VEkin', 'CPName'))
dataGCIE = pd.read_csv('protonGCIE.g4', comment='#', index_col=False, names=('Track','ParentID', 'PDG', 'Ekin', 'x', 'y','z', 'Mx', 'My', 'Mz', 'time', 'w', 'Px', 'Py', 'Pz','Vx', 'Vy', 'Vz', 'VMx', 'VMy', 'VMz', 'VEkin', 'CPName'))
dataGCSR = pd.read_csv('protonGCSR.g4', comment='#', index_col=False, names=('Track','ParentID', 'PDG', 'Ekin', 'x', 'y','z', 'Mx', 'My', 'Mz', 'time', 'w', 'Px', 'Py', 'Pz','Vx', 'Vy', 'Vz', 'VMx', 'VMy', 'VMz', 'VEkin', 'CPName'))

# %%
proton = data3.loc[data3['PDG'] == 2212]
gamma = data3.loc[data3['PDG'] == 22]
neutron = data3.loc[data3['PDG'] == 2112]
el = data3.loc[data3['PDG']== 11]
pos = data3.loc[data3['PDG']== -11]

protonGC = dataGC.loc[dataGC['PDG'] == 2212]
gammaGC = dataGC.loc[dataGC['PDG'] == 22]
neutronGC = dataGC.loc[dataGC['PDG'] == 2112]
elGC = dataGC.loc[dataGC['PDG']== 11]
posGC = dataGC.loc[dataGC['PDG']== -11]

protonGCRK4 = dataGCRK4.loc[dataGCRK4['PDG'] == 2212]
gammaGCRK4 = dataGCRK4.loc[dataGCRK4['PDG'] == 22]
neutronGCRK4 = dataGCRK4.loc[dataGCRK4['PDG'] == 2112]
elGCRK4 = dataGCRK4.loc[dataGCRK4['PDG']== 11]
posGCRK4 = dataGCRK4.loc[dataGCRK4['PDG']== -11]

protonGCHEE = dataGCHEE.loc[dataGCHEE['PDG'] == 2212]
gammaGCHEE = dataGCHEE.loc[dataGCHEE['PDG'] == 22]
neutronGCHEE = dataGCHEE.loc[dataGCHEE['PDG'] == 2112]
elGCHEE = dataGCHEE.loc[dataGCHEE['PDG']== 11]
posGCHEE = dataGCHEE.loc[dataGCHEE['PDG']== -11]

protonGCHSR = dataGCHSR.loc[dataGCHSR['PDG'] == 2212]
gammaGCHSR = dataGCHSR.loc[dataGCHSR['PDG'] == 22]
neutronGCHSR = dataGCHSR.loc[dataGCHSR['PDG'] == 2112]
elGCHSR = dataGCHSR.loc[dataGCHSR['PDG']== 11]
posGCHSR = dataGCHSR.loc[dataGCHSR['PDG']== -11]

protonGCNys = dataGCNys.loc[dataGCNys['PDG'] == 2212]

protonGCDP78 = dataGCDP78.loc[dataGCDP78['PDG'] == 2212]

protonGCNys2 = dataGCNys2.loc[dataGCNys2['PDG'] == 2212]

protonGCIE = dataGCIE.loc[dataGCIE['PDG'] == 2212]

# %%
dipoleRK4 = 'logRK4.txt'
dipoleRK4 = pd.read_csv(dipoleRK4, delim_whitespace=True, comment=':', names=['step', 'x', 'y', 'z', 'Energy', 'dE', 'StepLength', 'TrackLength', 'NextVolume', 'ProcessName'])
dipoleRK4 = dipoleRK4.dropna()

# %%
dipoleHEE = 'logHEE.txt'
dipoleHEE = pd.read_csv(dipoleHEE, delim_whitespace=True, comment=':', names=['step', 'x', 'y', 'z', 'Energy', 'dE', 'StepLength', 'TrackLength', 'NextVolume', 'ProcessName'])
dipoleHEE = dipoleHEE.dropna()

dipoleHEE_1m = 'logHEE_1m.txt'
dipoleHEE_1m = pd.read_csv(dipoleHEE_1m, delim_whitespace=True, comment=':', names=['step', 'x', 'y', 'z', 'Energy', 'dE', 'StepLength', 'TrackLength', 'NextVolume', 'ProcessName'])
dipoleHEE_1m = dipoleHEE_1m.dropna()

dipoleHEE_1km = 'logHEE_1km.txt'
dipoleHEE_1km = pd.read_csv(dipoleHEE_1km, delim_whitespace=True, comment=':', names=['step', 'x', 'y', 'z', 'Energy', 'dE', 'StepLength', 'TrackLength', 'NextVolume', 'ProcessName'])
dipoleHEE_1km = dipoleHEE_1km.dropna()

# %%
#Using HEE
dipoleDCh1 = 'logDCh1.txt'
dipoleDCh1 = pd.read_csv(dipoleDCh1, delim_whitespace=True, comment=':', names=['step', 'x', 'y', 'z', 'Energy', 'dE', 'StepLength', 'TrackLength', 'NextVolume', 'ProcessName'])
dipoleDCh1 = dipoleDCh1.dropna()

dipoleDCh2 = 'logDCh2.txt'
dipoleDCh2 = pd.read_csv(dipoleDCh2, delim_whitespace=True, comment=':', names=['step', 'x', 'y', 'z', 'Energy', 'dE', 'StepLength', 'TrackLength', 'NextVolume', 'ProcessName'])
dipoleDCh2 = dipoleDCh2.dropna()

dipoleDCh3 = 'logDCh3.txt'
dipoleDCh3 = pd.read_csv(dipoleDCh3, delim_whitespace=True, comment=':', names=['step', 'x', 'y', 'z', 'Energy', 'dE', 'StepLength', 'TrackLength', 'NextVolume', 'ProcessName'])
dipoleDCh3 = dipoleDCh3.dropna()

dipoleDCh4 = 'logDCh4.txt'
dipoleDCh4 = pd.read_csv(dipoleDCh4, delim_whitespace=True, comment=':', names=['step', 'x', 'y', 'z', 'Energy', 'dE', 'StepLength', 'TrackLength', 'NextVolume', 'ProcessName'])
dipoleDCh4 = dipoleDCh4.dropna()

dipoleDCh5 = 'logDCh5.txt'
dipoleDCh5 = pd.read_csv(dipoleDCh5, delim_whitespace=True, comment=':', names=['step', 'x', 'y', 'z', 'Energy', 'dE', 'StepLength', 'TrackLength', 'NextVolume', 'ProcessName'])
dipoleDCh5 = dipoleDCh5.dropna()

dipoleDCh6 = 'logDCh6.txt'
dipoleDCh6 = pd.read_csv(dipoleDCh6, delim_whitespace=True, comment=':', names=['step', 'x', 'y', 'z', 'Energy', 'dE', 'StepLength', 'TrackLength', 'NextVolume', 'ProcessName'])
dipoleDCh6 = dipoleDCh6.dropna()

# %%
dipoleChords1 = 'logChords1.txt'
dipoleChords1 = pd.read_csv(dipoleChords1, delim_whitespace=True, comment=':', names=['step', 'x', 'y', 'z', 'Energy', 'dE', 'StepLength', 'TrackLength', 'NextVolume', 'ProcessName'])
dipoleChords1 = dipoleChords1.dropna()

dipoleChords2 = 'logChords2.txt'
dipoleChords2 = pd.read_csv(dipoleChords2, delim_whitespace=True, comment=':', names=['step', 'x', 'y', 'z', 'Energy', 'dE', 'StepLength', 'TrackLength', 'NextVolume', 'ProcessName'])
dipoleChords2 = dipoleChords2.dropna()

# %%
dipoleHSR = 'logHSR.txt'
dipoleHSR = pd.read_csv(dipoleHSR, delim_whitespace=True, comment=':', names=['step', 'x', 'y', 'z', 'Energy', 'dE', 'StepLength', 'TrackLength', 'NextVolume', 'ProcessName'])
dipoleHSR = dipoleHSR.dropna()

# %%
dipoleNYS = 'logNYS.txt'
dipoleNYS = pd.read_csv(dipoleNYS, delim_whitespace=True, comment=':', names=['step', 'x', 'y', 'z', 'Energy', 'dE', 'StepLength', 'TrackLength', 'NextVolume', 'ProcessName'])
dipoleNYS = dipoleNYS.dropna()

# %%
dipoleEE = 'logEE.txt'
dipoleEE = pd.read_csv(dipoleEE, delim_whitespace=True, comment=':', names=['step', 'x', 'y', 'z', 'Energy', 'dE', 'StepLength', 'TrackLength', 'NextVolume', 'ProcessName'])
dipoleEE = dipoleEE.dropna()

# %%
# %matplotlib nbagg

Fig_Chords1 = plt.figure()
#plt.plot(dipole15_4000.x*1E-6, dipole15_4000.z*1E-6, markersize=1.5, label='$15^\circ$', lw=0.5)
plt.plot(proton.x*1e-5, proton.z*1e-5, markersize=1.5, label='$proton$', lw=0.5)
plt.plot(protonGC.x*1e-5, protonGC.z*1e-5, markersize=1.5, label='$protonGCEE$', lw=0.5)
plt.plot(protonGCRK4.x*1e-5, protonGCRK4.z*1e-5, markersize=1.5, label='$protonGCRK4$', lw=0.5)
plt.plot(protonGCHEE.x*1e-5, protonGCHEE.z*1e-5, markersize=1.5, label='$protonGCHEE$', lw=0.5)
plt.plot(protonGCHSR.x*1e-5, protonGCHSR.z*1e-5, markersize=1.5, label='$protonGCHSR$', lw=0.5)
plt.plot(protonGCNys.x*1e-5, protonGCNys.z*1e-5, markersize=1.5, label='$protonGCNys$', lw=0.5)
plt.plot(protonGCDP78.x*1e-5, protonGCDP78.z*1e-5, markersize=1.5, label='$protonGCDP78$', lw=0.5)



#plt.plot(dipoleChords2.x*1E-6, dipoleChords2.z*1E-6, markersize=1.5, label='$Chords2$', lw=0.5)




#plt.plot(dipoleHEE_1m.x*1E-6, dipoleHEE_1m.z*1E-6, markersize=1.5, label='$HEE \,1m$', lw=0.5)
#plt.plot(dipoleHEE_1km.x*1E-6, dipoleHEE_1km.z*1E-6, markersize=1.5, label='$HEE \,1km$', lw=0.5)



#plt.plot(dipole25_4000.x*1E-6, dipole25_4000.z*1E-6, markersize=1.5, label='$25^\circ$', lw=0.5)
#plt.plot(dipole35_4000.x*1E-6, dipole35_4000.z*1E-6, markersize=1.5, label='$35^\circ$', lw=0.5)


plt.xlabel('y [km]')
plt.ylabel('z [km]')
plt.legend(markerscale=5.0)
#plt.title('Proton 500 Mev 20 deg diff. altitudes XZ plane')
#plt.savefig('proton_pa_XZ.png')
#plt.plot(data.y, data.z, 'o', markersize=1.5, label='xy')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
Fig_Chords1 = plt.figure()
#plt.plot(dipole15_4000.x*1E-6, dipole15_4000.z*1E-6, markersize=1.5, label='$15^\circ$', lw=0.5)
# plt.plot(proton.y*1e-5, proton.z*1e-5, markersize=1.5, label='$proton$', lw=0.5)
# plt.plot(protonGC.y*1e-5, protonGC.z*1e-5, markersize=1.5, label='$protonGCEE$', lw=0.5)
# plt.plot(protonGCRK4.y*1e-5, protonGCRK4.z*1e-5, markersize=1.5, label='$protonGCRK4$', lw=0.5)
# plt.plot(protonGCHEE.y*1e-5, protonGCHEE.z*1e-5, markersize=1.5, label='$protonGCHEE$', lw=0.5)
# plt.plot(protonGCHSR.y*1e-5, protonGCHSR.z*1e-5, markersize=1.5, label='$protonGCHSR$', lw=0.5)
plt.plot(protonGCNys.y*1e-5, protonGCNys.z*1e-5, markersize=1.5, label='$protonGCNys$', lw=0.5)
plt.plot(protonGCDP78.y*1e-5, protonGCDP78.z*1e-5, markersize=1.5, label='$protonGCDP78$', lw=0.5)
plt.plot(protonGCIE.y*1e-5, protonGCIE.z*1e-5, markersize=1.5, label='$protonGCIE$', lw=0.5)





#plt.plot(dipoleChords2.x*1E-6, dipoleChords2.z*1E-6, markersize=1.5, label='$Chords2$', lw=0.5)




#plt.plot(dipoleHEE_1m.x*1E-6, dipoleHEE_1m.z*1E-6, markersize=1.5, label='$HEE \,1m$', lw=0.5)
#plt.plot(dipoleHEE_1km.x*1E-6, dipoleHEE_1km.z*1E-6, markersize=1.5, label='$HEE \,1km$', lw=0.5)



#plt.plot(dipole25_4000.x*1E-6, dipole25_4000.z*1E-6, markersize=1.5, label='$25^\circ$', lw=0.5)
#plt.plot(dipole35_4000.x*1E-6, dipole35_4000.z*1E-6, markersize=1.5, label='$35^\circ$', lw=0.5)


plt.xlabel('y [km]')
plt.ylabel('z [km]')
plt.legend(markerscale=5.0)
#plt.title('Proton 500 Mev 20 deg diff. altitudes XZ plane')
#plt.savefig('proton_pa_XZ.png')
#plt.plot(data.y, data.z, 'o', markersize=1.5, label='xy')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
Fig_Chords1 = plt.figure()
#plt.plot(dipole15_4000.x*1E-6, dipole15_4000.z*1E-6, markersize=1.5, label='$15^\circ$', lw=0.5)
plt.plot(proton.x*1e-5, proton.y*1e-5, markersize=1.5, label='$proton$', lw=0.5)
plt.plot(protonGC.x*1e-5, protonGC.y*1e-5, markersize=1.5, label='$protonGC$', lw=0.5)

#plt.plot(dipoleChords2.x*1E-6, dipoleChords2.z*1E-6, markersize=1.5, label='$Chords2$', lw=0.5)




#plt.plot(dipoleHEE_1m.x*1E-6, dipoleHEE_1m.z*1E-6, markersize=1.5, label='$HEE \,1m$', lw=0.5)
#plt.plot(dipoleHEE_1km.x*1E-6, dipoleHEE_1km.z*1E-6, markersize=1.5, label='$HEE \,1km$', lw=0.5)



#plt.plot(dipole25_4000.x*1E-6, dipole25_4000.z*1E-6, markersize=1.5, label='$25^\circ$', lw=0.5)
#plt.plot(dipole35_4000.x*1E-6, dipole35_4000.z*1E-6, markersize=1.5, label='$35^\circ$', lw=0.5)


plt.xlabel('y [km]')
plt.ylabel('z [km]')
plt.legend(markerscale=5.0)
#plt.title('Proton 500 Mev 20 deg diff. altitudes XZ plane')
#plt.savefig('proton_pa_XZ.png')
#plt.plot(data.y, data.z, 'o', markersize=1.5, label='xy')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
Fig_Chords1 = plt.figure()
#plt.plot(dipole15_4000.x*1E-6, dipole15_4000.z*1E-6, markersize=1.5, label='$15^\circ$', lw=0.5)
plt.plot(data.y*1E-6, data.z*1E-6, markersize=1.5, label='$Chords1$', lw=0.5)
#plt.plot(dipoleChords2.x*1E-6, dipoleChords2.z*1E-6, markersize=1.5, label='$Chords2$', lw=0.5)




#plt.plot(dipoleHEE_1m.x*1E-6, dipoleHEE_1m.z*1E-6, markersize=1.5, label='$HEE \,1m$', lw=0.5)
#plt.plot(dipoleHEE_1km.x*1E-6, dipoleHEE_1km.z*1E-6, markersize=1.5, label='$HEE \,1km$', lw=0.5)



#plt.plot(dipole25_4000.x*1E-6, dipole25_4000.z*1E-6, markersize=1.5, label='$25^\circ$', lw=0.5)
#plt.plot(dipole35_4000.x*1E-6, dipole35_4000.z*1E-6, markersize=1.5, label='$35^\circ$', lw=0.5)


plt.xlabel('x [km]')
plt.ylabel('z [km]')
plt.legend(markerscale=5.0)
#plt.title('Proton 500 Mev 20 deg diff. altitudes XZ plane')
#plt.savefig('proton_pa_XZ.png')
#plt.plot(data.y, data.z, 'o', markersize=1.5, label='xy')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
Fig_Chords1 = plt.figure()
#plt.plot(dipole15_4000.x*1E-6, dipole15_4000.z*1E-6, markersize=1.5, label='$15^\circ$', lw=0.5)
plt.plot(data.Mx*1E-6, data.Mz*1E-6, markersize=1.5, label='$Chords1$', lw=0.5)
#plt.plot(dipoleChords2.x*1E-6, dipoleChords2.z*1E-6, markersize=1.5, label='$Chords2$', lw=0.5)




#plt.plot(dipoleHEE_1m.x*1E-6, dipoleHEE_1m.z*1E-6, markersize=1.5, label='$HEE \,1m$', lw=0.5)
#plt.plot(dipoleHEE_1km.x*1E-6, dipoleHEE_1km.z*1E-6, markersize=1.5, label='$HEE \,1km$', lw=0.5)



#plt.plot(dipole25_4000.x*1E-6, dipole25_4000.z*1E-6, markersize=1.5, label='$25^\circ$', lw=0.5)
#plt.plot(dipole35_4000.x*1E-6, dipole35_4000.z*1E-6, markersize=1.5, label='$35^\circ$', lw=0.5)


plt.xlabel('x [km]')
plt.ylabel('z [km]')
plt.legend(markerscale=5.0)
#plt.title('Proton 500 Mev 20 deg diff. altitudes XZ plane')
#plt.savefig('proton_pa_XZ.png')
#plt.plot(data.y, data.z, 'o', markersize=1.5, label='xy')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
teslafig100 = plt.figure()
#plt.plot(dipole15_4000.x*1E-6, dipole15_4000.z*1E-6, markersize=1.5, label='$15^\circ$', lw=0.5)
plt.plot(dipoleDCh1.x*1E-6, dipoleDCh1.z*1E-6, markersize=1.5, label='$DCh1$', lw=0.5)
plt.plot(dipoleDCh2.x*1E-6, dipoleDCh2.z*1E-6, markersize=1.5, label='$DCh2$', lw=0.5)
plt.plot(dipoleDCh3.x*1E-6, dipoleDCh3.z*1E-6, markersize=1.5, label='$DCh3$', lw=0.5)
plt.plot(dipoleDCh4.x*1E-6, dipoleDCh4.z*1E-6, markersize=1.5, label='$DCh4$', lw=0.5)
plt.plot(dipoleDCh5.x*1E-6, dipoleDCh5.z*1E-6, markersize=1.5, label='$DCh5$', lw=0.5)
plt.plot(dipoleDCh6.x*1E-6, dipoleDCh6.z*1E-6, markersize=1.5, label='$DCh6$', lw=0.5)




#plt.plot(dipoleHEE_1m.x*1E-6, dipoleHEE_1m.z*1E-6, markersize=1.5, label='$HEE \,1m$', lw=0.5)
#plt.plot(dipoleHEE_1km.x*1E-6, dipoleHEE_1km.z*1E-6, markersize=1.5, label='$HEE \,1km$', lw=0.5)



#plt.plot(dipole25_4000.x*1E-6, dipole25_4000.z*1E-6, markersize=1.5, label='$25^\circ$', lw=0.5)
#plt.plot(dipole35_4000.x*1E-6, dipole35_4000.z*1E-6, markersize=1.5, label='$35^\circ$', lw=0.5)


plt.xlabel('x [km]')
plt.ylabel('z [km]')
plt.legend(markerscale=5.0)
#plt.title('Proton 500 Mev 20 deg diff. altitudes XZ plane')
#plt.savefig('proton_pa_XZ.png')
#plt.plot(data.y, data.z, 'o', markersize=1.5, label='xy')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
teslafig100 = plt.figure()
#plt.plot(dipole15_4000.x*1E-6, dipole15_4000.z*1E-6, markersize=1.5, label='$15^\circ$', lw=0.5)
plt.plot(dipoleDCh1.y*1E-6, dipoleDCh1.z*1E-6, markersize=1.5, label='$DCh1$', lw=0.5)
plt.plot(dipoleDCh2.y*1E-6, dipoleDCh2.z*1E-6, markersize=1.5, label='$DCh2$', lw=0.5)
plt.plot(dipoleDCh3.y*1E-6, dipoleDCh3.z*1E-6, markersize=1.5, label='$DCh3$', lw=0.5)
plt.plot(dipoleDCh4.y*1E-6, dipoleDCh4.z*1E-6, markersize=1.5, label='$DCh4$', lw=0.5)
plt.plot(dipoleDCh5.y*1E-6, dipoleDCh5.z*1E-6, markersize=1.5, label='$DCh5$', lw=0.5)
plt.plot(dipoleDCh6.y*1E-6, dipoleDCh6.z*1E-6, markersize=1.5, label='$DCh6$', lw=0.5)





#plt.plot(dipoleHEE_1m.x*1E-6, dipoleHEE_1m.z*1E-6, markersize=1.5, label='$HEE \,1m$', lw=0.5)
#plt.plot(dipoleHEE_1km.x*1E-6, dipoleHEE_1km.z*1E-6, markersize=1.5, label='$HEE \,1km$', lw=0.5)



#plt.plot(dipole25_4000.x*1E-6, dipole25_4000.z*1E-6, markersize=1.5, label='$25^\circ$', lw=0.5)
#plt.plot(dipole35_4000.x*1E-6, dipole35_4000.z*1E-6, markersize=1.5, label='$35^\circ$', lw=0.5)


plt.xlabel('y [km]')
plt.ylabel('z [km]')
plt.legend(markerscale=5.0)
plt.xlim(-5,5)
#plt.title('Proton 500 Mev 20 deg diff. altitudes XZ plane')
#plt.savefig('proton_pa_XZ.png')
#plt.plot(data.y, data.z, 'o', markersize=1.5, label='xy')
# Out:
# <img src="data:image/png;base64,..." width="640">
# (-5, 5)

# %%
teslafig100 = plt.figure()
#plt.plot(dipole15_4000.x*1E-6, dipole15_4000.z*1E-6, markersize=1.5, label='$15^\circ$', lw=0.5)
plt.plot(dipoleHEE.x*1E-6, dipoleHEE.z*1E-6, markersize=1.5, label='$HEE$', lw=0.5)
plt.plot(dipoleHEE_1m.x*1E-6, dipoleHEE_1m.z*1E-6, markersize=1.5, label='$HEE \,1m$', lw=0.5)
plt.plot(dipoleHEE_1km.x*1E-6, dipoleHEE_1km.z*1E-6, markersize=1.5, label='$HEE \,1km$', lw=0.5)



#plt.plot(dipole25_4000.x*1E-6, dipole25_4000.z*1E-6, markersize=1.5, label='$25^\circ$', lw=0.5)
#plt.plot(dipole35_4000.x*1E-6, dipole35_4000.z*1E-6, markersize=1.5, label='$35^\circ$', lw=0.5)


plt.xlabel('x [km]')
plt.ylabel('z [km]')
plt.legend(markerscale=5.0)
#plt.title('Proton 500 Mev 20 deg diff. altitudes XZ plane')
#plt.savefig('proton_pa_XZ.png')
#plt.plot(data.y, data.z, 'o', markersize=1.5, label='xy')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
teslafig100 = plt.figure()
#plt.plot(dipole15_4000.x*1E-6, dipole15_4000.z*1E-6, markersize=1.5, label='$15^\circ$', lw=0.5)
plt.plot(dipoleHEE.y*1E-6, dipoleHEE.z*1E-6, markersize=1.5, label='$HEE$', lw=0.5)
plt.plot(dipoleHEE_1m.y*1E-6, dipoleHEE_1m.z*1E-6, markersize=1.5, label='$HEE \,1m$', lw=0.5)
plt.plot(dipoleHEE_1km.y*1E-6, dipoleHEE_1km.z*1E-6, markersize=1.5, label='$HEE \,1km$', lw=0.5)



#plt.plot(dipole25_4000.x*1E-6, dipole25_4000.z*1E-6, markersize=1.5, label='$25^\circ$', lw=0.5)
#plt.plot(dipole35_4000.x*1E-6, dipole35_4000.z*1E-6, markersize=1.5, label='$35^\circ$', lw=0.5)


plt.xlabel('y [km]')
plt.ylabel('z [km]')
plt.legend(markerscale=5.0)
plt.xlim(-5, 5)
#plt.title('Proton 500 Mev 20 deg diff. altitudes XZ plane')
#plt.savefig('proton_pa_XZ.png')
#plt.plot(data.y, data.z, 'o', markersize=1.5, label='xy')
# Out:
# <img src="data:image/png;base64,..." width="640">
# (-5, 5)

# %%
# %matplotlib nbagg
teslafig100 = plt.figure()
#plt.plot(dipole15_4000.x*1E-6, dipole15_4000.z*1E-6, markersize=1.5, label='$15^\circ$', lw=0.5)
plt.plot(dipoleRK4.x*1E-6, dipoleRK4.z*1E-6, markersize=1.5, label='$RK4$', lw=0.5)
plt.plot(dipoleHEE.x*1E-6, dipoleHEE.z*1E-6, markersize=1.5, label='$HEE$', lw=0.5)
plt.plot(dipoleHSR.x*1E-6, dipoleHSR.z*1E-6, markersize=1.5, label='$HSR$', lw=0.5)
plt.plot(dipoleNYS.x*1E-6, dipoleNYS.z*1E-6, markersize=1.5, label='$NYS$', lw=0.5)
plt.plot(dipoleEE.x*1E-6, dipoleEE.z*1E-6, markersize=1.5, label='$EE$', lw=0.5)






#plt.plot(dipole25_4000.x*1E-6, dipole25_4000.z*1E-6, markersize=1.5, label='$25^\circ$', lw=0.5)
#plt.plot(dipole35_4000.x*1E-6, dipole35_4000.z*1E-6, markersize=1.5, label='$35^\circ$', lw=0.5)


plt.xlabel('x [km]')
plt.ylabel('z [km]')
plt.legend(markerscale=5.0)
#plt.title('Proton 500 Mev 20 deg diff. altitudes XZ plane')
#plt.savefig('proton_pa_XZ.png')
#plt.plot(data.y, data.z, 'o', markersize=1.5, label='xy')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
teslafig100 = plt.figure()
#plt.plot(dipole15_4000.x*1E-6, dipole15_4000.z*1E-6, markersize=1.5, label='$15^\circ$', lw=0.5)
plt.plot(dipoleRK4.y*1E-6, dipoleRK4.z*1E-6, markersize=1.5, label='$RK4$', lw=0.5)
plt.plot(dipoleHEE.y*1E-6, dipoleHEE.z*1E-6, markersize=1.5, label='$HEE$', lw=0.5)
plt.plot(dipoleHSR.y*1E-6, dipoleHSR.z*1E-6, markersize=1.5, label='$HSR$', lw=0.5)
plt.plot(dipoleNYS.y*1E-6, dipoleNYS.z*1E-6, markersize=1.5, label='$NYS$', lw=0.5)




#plt.plot(dipole25_4000.x*1E-6, dipole25_4000.z*1E-6, markersize=1.5, label='$25^\circ$', lw=0.5)
#plt.plot(dipole35_4000.x*1E-6, dipole35_4000.z*1E-6, markersize=1.5, label='$35^\circ$', lw=0.5)


plt.xlabel('y [km]')
plt.ylabel('z [km]')
plt.legend(markerscale=5.0)
#plt.title('Proton 500 Mev 20 deg diff. altitudes XZ plane')
#plt.savefig('proton_pa_XZ.png')
#plt.plot(data.y, data.z, 'o', markersize=1.5, label='xy')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
teslafig100 = plt.figure()
#plt.plot(dipole15_4000.x*1E-6, dipole15_4000.z*1E-6, markersize=1.5, label='$15^\circ$', lw=0.5)
plt.plot(dipoleRK4.x*1E-6, dipoleRK4.y*1E-6, markersize=1.5, label='$RK4$', lw=0.5)
plt.plot(dipoleHEE.x*1E-6, dipoleHEE.y*1E-6-0.1, markersize=1.5, label='$HEE$', lw=0.5)
plt.plot(dipoleHSR.x*1E-6, dipoleHSR.y*1E-6-0.2, markersize=1.5, label='$HSR$', lw=0.5)
plt.plot(dipoleNYS.x*1E-6, dipoleNYS.y*1E-6-0.3, markersize=1.5, label='$NYS$', lw=0.5)


#plt.plot(dipole35_4000.x*1E-6-200, dipole35_4000.z*1E-6-200, markersize=1.5, label='$35^\circ$', lw=0.5)




#plt.plot(dipole25_4000.x*1E-6, dipole25_4000.z*1E-6, markersize=1.5, label='$25^\circ$', lw=0.5)
#plt.plot(dipole35_4000.x*1E-6, dipole35_4000.z*1E-6, markersize=1.5, label='$35^\circ$', lw=0.5)


plt.xlabel('x [km]')
plt.ylabel('y [km]')
plt.legend(markerscale=5.0, loc=1)
#plt.title('Proton 500 Mev 20 deg diff. altitudes XZ plane')
#plt.savefig('proton_pa_XZ.png')
#plt.plot(data.y, data.z, 'o', markersize=1.5, label='xy')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import matplotlib as mpl
from mpl_toolkits.mplot3d import Axes3D

# %%
fig = plt.figure(figsize=(12, 9), dpi=95)
ax = fig.add_subplot(111, projection='3d')
surf=ax.scatter3D(protonGCNys.x*1E-5, protonGCNys.y*1E-5, protonGCNys.z*1E-5,lw=0.2, c= protonGCNys.time, cmap=plt.cm.gnuplot_r,label='Energy (GeV)')
surf=ax.scatter3D(protonGCRK4.x*1E-5, protonGCRK4.y*1E-5, protonGCRK4.z*1E-5,lw=0.2, c= protonGCRK4.time, cmap=plt.cm.gnuplot_r,label='Energy (GeV)')
surf=ax.scatter3D(protonGCHEE.x*1E-5, protonGCHEE.y*1E-5, protonGCHEE.z*1E-5,lw=0.2, c= protonGCHEE.time, cmap=plt.cm.gnuplot_r,label='Energy (GeV)')

#ax.plot(el.xx, el.yy, el.zz,'o')
fig.colorbar(surf, shrink=0.7, extend='min', label='Time (s)')
#fig.colorbar(surf8000, shrink=0.7, extend='min', label='Energy (MeV)')

#plt.title('Electrons Vertex')
ax.view_init(elev=0)
#ax.set_zlim(0,-200)


ax.set_xlabel('X (km)')
ax.set_ylabel('Y (km)')
ax.set_zlabel('Z (km)')
#ax.set_zlim(-500,10)
#plt.savefig('proton_-500_3d.png')
# Out:
# <img src="data:image/png;base64,..." width="1140">
# Text(0.5,0,u'Z (km)')

# %%
#np.max(el.loc[el['Track']==100])
# Out:
# Track               100
# ParentID              1
# PDG                  11
# Ekin           0.111043
# x           4.47441e+08
# y              -5085.33
# z          -8.04237e+07
# Mx             0.673313
# My             0.893647
# Mz            -0.382348
# time          0.0343515
# w                     1
# Px                    0
# Py                    0
# Pz                    0
# Vx          4.47441e+08
# Vy             -4693.73
# Vz         -8.04234e+07
# VMx           -0.258377
# VMy            0.847448
# VMz           -0.463759
# VEkin          0.114494
# CPName            hIoni
# dtype: object

# %%
fig = plt.figure(figsize=(12, 9), dpi=95)
ax = fig.add_subplot(111, projection='3d')
surf=ax.scatter3D(dipole20_top.x*1E-6, dipole20_top.y*1E-6, dipole20_top.z*1E-6,lw=0.2, c= dipole20_top.Energy, cmap=plt.cm.gnuplot_r,label='Energy (GeV)')
surf8000=ax.scatter3D(dipole20_8000.x*1E-6, dipole20_8000.y*1E-6, dipole20_8000.z*1E-6,lw=0.2, c= dipole20_8000.Energy, cmap=plt.cm.gnuplot_r,label='Energy (GeV)')
surf6000=ax.scatter3D(dipole20_6000.x*1E-6, dipole20_6000.y*1E-6, dipole20_6000.z*1E-6,lw=0.2, c= dipole20_6000.Energy, cmap=plt.cm.gnuplot_r,label='Energy (GeV)')
surf4000=ax.scatter3D(dipole20_4000.x*1E-6, dipole20_4000.y*1E-6, dipole20_4000.z*1E-6,lw=0.2, c= dipole20_4000.Energy, cmap=plt.cm.gnuplot_r,label='Energy (GeV)')
surf2000=ax.scatter3D(dipole20_2000.x*1E-6, dipole20_2000.y*1E-6, dipole20_2000.z*1E-6,lw=0.2, c= dipole20_2000.Energy, cmap=plt.cm.gnuplot_r,label='Energy (GeV)')
surf500=ax.scatter3D(dipole20_500.x*1E-6, dipole20_500.y*1E-6, dipole20_500.z*1E-6,lw=0.2, c= dipole20_500.Energy, cmap=plt.cm.gnuplot_r,label='Energy (GeV)')
surf100=ax.scatter3D(dipole20_100.x*1E-6, dipole20_100.y*1E-6, dipole20_100.z*1E-6,lw=0.2, c= dipole20_100.Energy, cmap=plt.cm.gnuplot_r,label='Energy (GeV)')

#ax.plot(el.xx, el.yy, el.zz,'o')
fig.colorbar(surf, shrink=0.7, extend='min', label='Energy (MeV)')
#fig.colorbar(surf8000, shrink=0.7, extend='min', label='Energy (MeV)')

#plt.title('Electrons Vertex')
ax.view_init(elev=0)
#ax.set_zlim(0,-200)


ax.set_xlabel('X (km)')
ax.set_ylabel('Y (km)')
ax.set_zlabel('Z (km)')
#ax.set_zlim(-500,10)
plt.savefig('proton_h_3d.png')
# Out:
# <img src="data:image/png;base64,..." width="1140">

# %%
plt.legend?

# %%
fig = plt.figure(figsize=(12, 9), dpi=95)
ax = fig.add_subplot(111, projection='3d')
surf=ax.scatter3D(dipole35_4000.x*1E-6, dipole35_4000.y*1E-6, dipole35_4000.z*1E-6,lw=0.2, c= dipole35_4000.Energy, cmap=plt.cm.gnuplot_r,label='Energy (GeV)')
#ax.plot(el.xx, el.yy, el.zz,'o')
fig.colorbar(surf, shrink=0.7, extend='min', label='Energy (MeV)')
#plt.title('Electrons Vertex')
ax.view_init(elev=0)
#ax.set_zlim(0,-200)


ax.set_xlabel('X (km)')
ax.set_ylabel('Y (km)')
ax.set_zlabel('Z (km)')
#plt.savefig('tp_3dcolormap.png')
# Out:
# <img src="data:image/png;base64,..." width="1140">
# Text(0.5,0,u'Z (km)')

# %%
fig = plt.figure(figsize=(12, 9), dpi=95)
ax = fig.add_subplot(111, projection='3d')
surf=ax.scatter3D(teslaZXY10000.x*1E-6, teslaZXY10000.y*1E-6, teslaZXY10000.z*1E-6,lw=0.2, c= teslaZXY10000.Energy, cmap=plt.cm.gnuplot_r,label='Energy (GeV)')
#ax.plot(el.xx, el.yy, el.zz,'o')
fig.colorbar(surf, shrink=0.7, extend='min', label='Energy (MeV)')
#plt.title('Electrons Vertex')
ax.view_init(elev=0)
#ax.set_zlim(0,-200)

ax.set_zlim(-1200, 10)


ax.set_xlabel('X (km)')
ax.set_ylabel('Y (km)')
ax.set_zlabel('Z (km)')
#plt.savefig('tp_3dcolormap.png')
# Out:
# <img src="data:image/png;base64,..." width="1140">
# Text(0.5,0,u'Z (km)')

# %%
fig = plt.figure(figsize=(12, 9), dpi=95)
ax = fig.add_subplot(111, projection='3d')
surf=ax.scatter3D(teslaZXY.x*1E-6, teslaZXY.y*1E-6, teslaZXY.z*1E-6,lw=0.2, c= teslaZXY.Energy, cmap=plt.cm.gnuplot_r,label='Energy (GeV)')
#ax.plot(el.xx, el.yy, el.zz,'o')
fig.colorbar(surf, shrink=0.7, extend='min', label='Energy (MeV)')
#plt.title('Electrons Vertex')
ax.view_init(elev=0)
#ax.set_zlim(0,-200)


ax.set_xlabel('X (km)')
ax.set_ylabel('Y (km)')
ax.set_zlabel('Z (km)')
#plt.savefig('tp_3dcolormap.png')
# Out:
# <img src="data:image/png;base64,..." width="1140">
# Text(0.5,0,u'Z (km)')

# %%
fig = plt.figure(figsize=(12, 9), dpi=95)
ax = fig.add_subplot(111, projection='3d')
surf=ax.scatter3D(data.Mx, data.My, data.Mz,lw=0.2)
#surf2=ax.scatter3D(teslaZXY10000.x*1E-6, teslaZXY10000.y*1E-6, teslaZXY10000.z*1E-6,lw=0.2, c= teslaZXY10000.Energy, cmap=plt.cm.gnuplot_r,label='Energy (GeV)')

#ax.plot(el.xx, el.yy, el.zz,'o')
#fig.colorbar(surf, shrink=0.7, extend='min', label='Energy (MeV)')
#fig.colorbar(surf2, shrink=0.7, extend='min', label='Energy (MeV)')
#plt.title('Electrons Vertex')
ax.view_init(elev=0)
#ax.set_zlim(0,-200)


ax.set_xlabel('X (km)')
ax.set_ylabel('Y (km)')
ax.set_zlabel('Z (km)')
#plt.savefig('tp_3dcolormap.png')
# Out:
# <img src="data:image/png;base64,..." width="1140">
# Text(0.5,0,u'Z (km)')

# %%
fig = plt.figure(figsize=(12, 9), dpi=95)
ax = fig.add_subplot(111, projection='3d')
surf=ax.scatter3D(teslaZXY.x*1E-6, teslaZXY.y*1E-6, teslaZXY.z*1E-6,lw=0.2, c= teslaZXY.Energy, cmap=plt.cm.gnuplot_r,label='Energy (GeV)')
#ax.plot(el.xx, el.yy, el.zz,'o')
fig.colorbar(surf, shrink=0.7, extend='min', label='Energy (MeV)')
#plt.title('Electrons Vertex')
ax.view_init(elev=0)
#ax.set_zlim(0,-200)


ax.set_xlabel('X (km)')
ax.set_ylabel('Y (km)')
ax.set_zlabel('Z (km)')
#plt.savefig('tp_3dcolormap.png')
# Out:
# <img src="data:image/png;base64,..." width="1140">
# Text(0.5,0,u'Z (km)')

# %%
fig = plt.figure(figsize=(12, 9), dpi=95)
ax = fig.add_subplot(111, projection='3d')
surf=ax.scatter3D(tesla_neg.x*1E-6, tesla_neg.y*1E-6, tesla_neg.z*1E-6,lw=0.2, c= tesla_neg.Energy, cmap=plt.cm.gnuplot_r,label='Energy (GeV)')
#ax.plot(el.xx, el.yy, el.zz,'o')
fig.colorbar(surf, shrink=0.7, extend='min', label='Energy (MeV)')
#plt.title('Electrons Vertex')
ax.view_init(elev=0)
#ax.set_zlim(0,-200)


ax.set_xlabel('X (km)')
ax.set_ylabel('Y (km)')
ax.set_zlabel('Z (km)')
#plt.savefig('tp_3dcolormap.png')
# Out:
# <img src="data:image/png;base64,..." width="1140">
# Text(0.5,0,u'Z (km)')

# %%
np.reshape?

# %%
fig = plt.figure(figsize=(12, 9), dpi=95)
ax = fig.add_subplot(111, projection='3d')
surf=ax.scatter3D(tesla_mag10.x*1E-6, tesla_mag10.y*1E-6, tesla_mag10.z*1E-6,lw=0.2, c= tesla_mag10.Energy, cmap=plt.cm.gnuplot_r,label='Energy (GeV)')
#ax.plot(el.xx, el.yy, el.zz,'o')
fig.colorbar(surf, shrink=0.7, extend='min', label='Energy (MeV)')
#plt.title('Electrons Vertex')
ax.view_init(elev=0)
#ax.set_zlim(0,-200)


ax.set_xlabel('X (km)')
ax.set_ylabel('Y (km)')
ax.set_zlabel('Z (km)')
#plt.savefig('tp_3dcolormap.png')
# Out:
# <img src="data:image/png;base64,..." width="1140">
# Text(0.5,0,u'Z (km)')

# %%
fig = plt.figure(figsize=(12, 9), dpi=95)
ax = fig.add_subplot(111, projection='3d')
surf=ax.scatter3D(tesla100.x*1E-6, tesla100.y*1E-6, tesla100.z*1E-6,lw=0.2, c= tesla100.Energy, cmap=plt.cm.gnuplot_r,label='Energy (GeV)')
#ax.plot(el.xx, el.yy, el.zz,'o')
fig.colorbar(surf, shrink=0.7, extend='min', label='Energy (MeV)')
#plt.title('Electrons Vertex')
ax.view_init(elev=0)
#ax.set_zlim(0,-200)


ax.set_xlabel('X (km)')
ax.set_ylabel('Y (km)')
ax.set_zlabel('Z (km)')
#plt.savefig('tp_3dcolormap.png')

# %%
fig = plt.figure(figsize=(12, 9), dpi=95)
ax = fig.add_subplot(111, projection='3d')
surf=ax.scatter3D(teslaTop.x*1E-6, teslaTop.y*1E-6, teslaTop.z*1E-6,lw=0.2, c= teslaTop.Energy, cmap=plt.cm.gnuplot_r,label='Energy (GeV)')
#ax.plot(el.xx, el.yy, el.zz,'o')
fig.colorbar(surf, shrink=0.7, extend='min', label='Energy (MeV)')
#plt.title('Electrons Vertex')
ax.view_init(elev=0)
#ax.set_zlim(0,-200)


ax.set_xlabel('X (km)')
ax.set_ylabel('Y (km)')
ax.set_zlabel('Z (km)')
#plt.savefig('tp_3dcolormap.png')

# %%
fig = plt.figure(figsize=(12, 9), dpi=95)
ax = fig.add_subplot(111, projection='3d')
surf=ax.scatter3D(tesla100250.x*1E-6, tesla100250.y*1E-6, tesla100250.z*1E-6,lw=0.2, c= tesla100250.Energy, cmap=plt.cm.gnuplot_r,label='Energy (GeV)')
#ax.plot(el.xx, el.yy, el.zz,'o')
fig.colorbar(surf, shrink=0.7, extend='min', label='Energy (MeV)')
#plt.title('Electrons Vertex')
ax.view_init(elev=0)
#ax.set_zlim(0,-200)


ax.set_xlabel('X (km)')
ax.set_ylabel('Y (km)')
ax.set_zlabel('Z (km)')
#plt.savefig('tp_3dcolormap.png')

# %%
fig = plt.figure(figsize=(12, 9), dpi=95)
ax = fig.add_subplot(111, projection='3d')
surf=ax.scatter3D(tesla100.x*1E-6, tesla100.y*1E-6, tesla100.z*1E-6,lw=0.2, c= tesla100.Energy, cmap=plt.cm.gnuplot_r,label='Energy (GeV)')
#ax.plot(el.xx, el.yy, el.zz,'o')
fig.colorbar(surf, shrink=0.7, extend='min', label='Energy (MeV)')
#plt.title('Electrons Vertex')
ax.view_init(elev=0)
#ax.set_zlim(0,-200)


ax.set_xlabel('X (km)')
ax.set_ylabel('Y (km)')
ax.set_zlabel('Z (km)')
#plt.savefig('tp_3dcolormap.png')

# %%
ls
# Out:
# AAA_A.out            el2                      readlogsfinal
# AAA_C.out            el3                      run0.mac
# AAA_F.out            el4                      runTest.mac
# CMakeLists.txt       el5                      runTestEnergy.mac
# GNUmakefile          el6                      script
# History              el7                      script.sh
# Makefile             el8                      solar.cc
# PurgMag3D.TABLE      el9                      solar.in
# README               electron7.txt            solar.out
# Solar_field.in       include/                 solar.py
# Solar_field.out      init_vis.mac             solar.pyc
# TESTTESLA.txt        log15_4000.txt           solar2.cc
# Tests.ipynb          log20_100.txt            solar_mag.py
# TreatedFile.txt      log20_2000.txt           solar_mag.pyc
# Untitled.ipynb       log20_4000.txt           src/
# build/               log20_500.txt            tesla100T.txt
# ...

# %%
el1 = 'el1'
el1 = pd.read_csv(el1, delim_whitespace=True, comment=':', names=['step', 'x', 'y', 'z', 'Energy', 'dE', 'StepLength', 'TrackLength', 'NextVolume', 'ProcessName'])
el1 = el1.dropna()

el2 = 'el2'
el2 = pd.read_csv(el2, delim_whitespace=True, comment=':', names=['step', 'x', 'y', 'z', 'Energy', 'dE', 'StepLength', 'TrackLength', 'NextVolume', 'ProcessName'])
el2 = el2.dropna()

el3 = 'el3'
el3 = pd.read_csv(el3, delim_whitespace=True, comment=':', names=['step', 'x', 'y', 'z', 'Energy', 'dE', 'StepLength', 'TrackLength', 'NextVolume', 'ProcessName'])
el3 = el3.dropna()

el4 = 'el4'
el4 = pd.read_csv(el4, delim_whitespace=True, comment=':', names=['step', 'x', 'y', 'z', 'Energy', 'dE', 'StepLength', 'TrackLength', 'NextVolume', 'ProcessName'])
el4 = el4.dropna()

el5 = 'el5'
el5 = pd.read_csv(el5, delim_whitespace=True, comment=':', names=['step', 'x', 'y', 'z', 'Energy', 'dE', 'StepLength', 'TrackLength', 'NextVolume', 'ProcessName'])
el5 = el5.dropna()

el6 = 'el6'
el6 = pd.read_csv(el6, delim_whitespace=True, comment=':', names=['step', 'x', 'y', 'z', 'Energy', 'dE', 'StepLength', 'TrackLength', 'NextVolume', 'ProcessName'])
el6 = el6.dropna()

el7 = 'el7'
el7 = pd.read_csv(el7, delim_whitespace=True, comment=':', names=['step', 'x', 'y', 'z', 'Energy', 'dE', 'StepLength', 'TrackLength', 'NextVolume', 'ProcessName'])
el7 = el7.dropna()

el8 = 'el8'
el8 = pd.read_csv(el8, delim_whitespace=True, comment=':', names=['step', 'x', 'y', 'z', 'Energy', 'dE', 'StepLength', 'TrackLength', 'NextVolume', 'ProcessName'])
el8 = el8.dropna()

el9 = 'el9'
el9 = pd.read_csv(el9, delim_whitespace=True, comment=':', names=['step', 'x', 'y', 'z', 'Energy', 'dE', 'StepLength', 'TrackLength', 'NextVolume', 'ProcessName'])
el9 = el9.dropna()

el10 = 'el10'
el10 = pd.read_csv(el10, delim_whitespace=True, comment=':', names=['step', 'x', 'y', 'z', 'Energy', 'dE', 'StepLength', 'TrackLength', 'NextVolume', 'ProcessName'])
el10 = el10.dropna()

el11 = 'el11'
el11 = pd.read_csv(el11, delim_whitespace=True, comment=':', names=['step', 'x', 'y', 'z', 'Energy', 'dE', 'StepLength', 'TrackLength', 'NextVolume', 'ProcessName'])
el11 = el11.dropna()

el12 = 'el12'
el12 = pd.read_csv(el12, delim_whitespace=True, comment=':', names=['step', 'x', 'y', 'z', 'Energy', 'dE', 'StepLength', 'TrackLength', 'NextVolume', 'ProcessName'])
el12 = el12.dropna()

el13 = 'el13'
el13 = pd.read_csv(el13, delim_whitespace=True, comment=':', names=['step', 'x', 'y', 'z', 'Energy', 'dE', 'StepLength', 'TrackLength', 'NextVolume', 'ProcessName'])
el13 = el13.dropna()

# %%
teslafig100 = plt.figure()
#plt.plot(dipole15_4000.x*1E-6, dipole15_4000.z*1E-6, markersize=1.5, label='$15^\circ$', lw=0.5)
plt.plot(el1.x*1E-6, el1.z*1E-6, markersize=1.5, label='$el1$', lw=0.5)
plt.plot(el2.x*1E-6, el2.z*1E-6, markersize=1.5, label='$el2$', lw=0.5)
plt.plot(el3.x*1E-6, el3.z*1E-6, markersize=1.5, label='$el3$', lw=0.5)
plt.plot(el4.x*1E-6, el4.z*1E-6, markersize=1.5, label='$el4$', lw=0.5)
plt.plot(el5.x*1E-6, el5.z*1E-6, markersize=1.5, label='$el5$', lw=0.5)
plt.plot(el6.x*1E-6, el6.z*1E-6, markersize=1.5, label='$el6$', lw=0.5)
plt.plot(el7.x*1E-6, el7.z*1E-6, markersize=1.5, label='$el7$', lw=0.5)
plt.plot(el8.x*1E-6, el8.z*1E-6, markersize=1.5, label='$el8$', lw=0.5)
plt.plot(el9.x*1E-6, el9.z*1E-6, markersize=1.5, label='$el9$', lw=0.5)
plt.plot(el10.x*1E-6, el10.z*1E-6, markersize=1.5, label='$el10$', lw=0.5)
plt.plot(el11.x*1E-6, el11.z*1E-6, markersize=1.5, label='$el11$', lw=0.5)
plt.plot(el12.x*1E-6, el12.z*1E-6, markersize=1.5, label='$el12$', lw=0.5)
plt.plot(el13.x*1E-6, el13.z*1E-6, markersize=1.5, label='$el13$', lw=0.5)



#plt.plot(dipole25_4000.x*1E-6, dipole25_4000.z*1E-6, markersize=1.5, label='$25^\circ$', lw=0.5)
#plt.plot(dipole35_4000.x*1E-6, dipole35_4000.z*1E-6, markersize=1.5, label='$35^\circ$', lw=0.5)


plt.xlabel('x [km]')
plt.ylabel('z [km]')
plt.legend(markerscale=5.0)
plt.title('Proton 500 Mev 30 deg TOP XZ plane')
#plt.savefig('tp_xz.png')
#plt.plot(data.y, data.z, 'o', markersize=1.5, label='xy')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5,1,u'Proton 500 Mev 30 deg TOP XZ plane')

# %%
teslafig100 = plt.figure()
#plt.plot(dipole15_4000.x*1E-6, dipole15_4000.z*1E-6, markersize=1.5, label='$15^\circ$', lw=0.5)
#plt.plot(el1.x*1E-6, el1.z*1E-6, markersize=1.5, label='$el1$', lw=1.0)
# plt.plot(el2.x*1E-6, el2.z*1E-6, markersize=1.5, label='$el2$', lw=0.5)
# plt.plot(el3.x*1E-6, el3.z*1E-6, markersize=1.5, label='$el3$', lw=0.5)
# plt.plot(el4.x*1E-6, el4.z*1E-6, markersize=1.5, label='$el4$', lw=0.5)
# plt.plot(el5.x*1E-6, el5.z*1E-6, markersize=1.5, label='$el5$', lw=0.5)
# plt.plot(el6.x*1E-6, el6.z*1E-6, markersize=1.5, label='$el6$', lw=0.5)
# plt.plot(el7.x*1E-6, el7.z*1E-6, markersize=1.5, label='$el7$', lw=0.5)
# plt.plot(el8.x*1E-6, el8.z*1E-6, markersize=1.5, label='$el8$', lw=0.5)
# plt.plot(el9.x*1E-6, el9.z*1E-6, markersize=1.5, label='$el9$', lw=0.5)
# plt.plot(el10.x*1E-6, el10.z*1E-6, markersize=1.5, label='$el10$', lw=0.5)
# plt.plot(el11.x*1E-6, el11.z*1E-6, markersize=1.5, label='$el11$', lw=0.5)
# plt.plot(el12.x*1E-6, el12.z*1E-6, markersize=1.5, label='$el12$', lw=0.5)
plt.plot(el11.x*1E-6, el11.z*1E-6, markersize=1.5, label='$el13$', lw=0.5)



#plt.plot(dipole25_4000.x*1E-6, dipole25_4000.z*1E-6, markersize=1.5, label='$25^\circ$', lw=0.5)
#plt.plot(dipole35_4000.x*1E-6, dipole35_4000.z*1E-6, markersize=1.5, label='$35^\circ$', lw=0.5)


plt.xlabel('x [km]')
plt.ylabel('z [km]')
plt.legend(markerscale=5.0)
#plt.title('Proton 500 Mev 30 deg TOP XZ plane')
#plt.savefig('tp_xz.png')
#plt.plot(data.y, data.z, 'o', markersize=1.5, label='xy')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
teslafig100 = plt.figure()
#plt.plot(dipole15_4000.x*1E-6, dipole15_4000.z*1E-6, markersize=1.5, label='$15^\circ$', lw=0.5)
#plt.plot(el1.x*1E-6, el1.z*1E-6, markersize=1.5, label='$el1$', lw=1.0)
# plt.plot(el2.x*1E-6, el2.z*1E-6, markersize=1.5, label='$el2$', lw=0.5)
# plt.plot(el3.x*1E-6, el3.z*1E-6, markersize=1.5, label='$el3$', lw=0.5)
# plt.plot(el4.x*1E-6, el4.z*1E-6, markersize=1.5, label='$el4$', lw=0.5)
# plt.plot(el5.x*1E-6, el5.z*1E-6, markersize=1.5, label='$el5$', lw=0.5)
# plt.plot(el6.x*1E-6, el6.z*1E-6, markersize=1.5, label='$el6$', lw=0.5)
# plt.plot(el7.x*1E-6, el7.z*1E-6, markersize=1.5, label='$el7$', lw=0.5)
# plt.plot(el8.x*1E-6, el8.z*1E-6, markersize=1.5, label='$el8$', lw=0.5)
# plt.plot(el9.x*1E-6, el9.z*1E-6, markersize=1.5, label='$el9$', lw=0.5)
# plt.plot(el10.x*1E-6, el10.z*1E-6, markersize=1.5, label='$el10$', lw=0.5)
# plt.plot(el11.x*1E-6, el11.z*1E-6, markersize=1.5, label='$el11$', lw=0.5)
# plt.plot(el12.x*1E-6, el12.z*1E-6, markersize=1.5, label='$el12$', lw=0.5)
plt.plot(el11.y*1E-6, el11.z*1E-6, markersize=1.5, label='$el13$', lw=0.5)



#plt.plot(dipole25_4000.x*1E-6, dipole25_4000.z*1E-6, markersize=1.5, label='$25^\circ$', lw=0.5)
#plt.plot(dipole35_4000.x*1E-6, dipole35_4000.z*1E-6, markersize=1.5, label='$35^\circ$', lw=0.5)


plt.xlabel('x [km]')
plt.ylabel('z [km]')
plt.legend(markerscale=5.0)
#plt.title('Proton 500 Mev 30 deg TOP XZ plane')
#plt.savefig('tp_xz.png')
#plt.plot(data.y, data.z, 'o', markersize=1.5, label='xy')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
teslafig100 = plt.figure()
#plt.plot(dipole15_4000.x*1E-6, dipole15_4000.z*1E-6, markersize=1.5, label='$15^\circ$', lw=0.5)
#plt.plot(el1.x*1E-6, el1.z*1E-6, markersize=1.5, label='$el1$', lw=1.0)
# plt.plot(el2.x*1E-6, el2.z*1E-6, markersize=1.5, label='$el2$', lw=0.5)
# plt.plot(el3.x*1E-6, el3.z*1E-6, markersize=1.5, label='$el3$', lw=0.5)
# plt.plot(el4.x*1E-6, el4.z*1E-6, markersize=1.5, label='$el4$', lw=0.5)
# plt.plot(el5.x*1E-6, el5.z*1E-6, markersize=1.5, label='$el5$', lw=0.5)
# plt.plot(el6.x*1E-6, el6.z*1E-6, markersize=1.5, label='$el6$', lw=0.5)
# plt.plot(el7.x*1E-6, el7.z*1E-6, markersize=1.5, label='$el7$', lw=0.5)
# plt.plot(el8.x*1E-6, el8.z*1E-6, markersize=1.5, label='$el8$', lw=0.5)
# plt.plot(el9.x*1E-6, el9.z*1E-6, markersize=1.5, label='$el9$', lw=0.5)
# plt.plot(el10.x*1E-6, el10.z*1E-6, markersize=1.5, label='$el10$', lw=0.5)
# plt.plot(el11.x*1E-6, el11.z*1E-6, markersize=1.5, label='$el11$', lw=0.5)
# plt.plot(el12.x*1E-6, el12.z*1E-6, markersize=1.5, label='$el12$', lw=0.5)
plt.plot(el11.x*1E-6, el11.y*1E-6, markersize=1.5, label='$el13$', lw=0.5)



#plt.plot(dipole25_4000.x*1E-6, dipole25_4000.z*1E-6, markersize=1.5, label='$25^\circ$', lw=0.5)
#plt.plot(dipole35_4000.x*1E-6, dipole35_4000.z*1E-6, markersize=1.5, label='$35^\circ$', lw=0.5)


plt.xlabel('x [km]')
plt.ylabel('z [km]')
plt.legend(markerscale=5.0)
#plt.title('Proton 500 Mev 30 deg TOP XZ plane')
#plt.savefig('tp_xz.png')
#plt.plot(data.y, data.z, 'o', markersize=1.5, label='xy')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig = plt.figure(figsize=(12, 9), dpi=95)
ax = fig.add_subplot(111, projection='3d')
surf=ax.scatter3D(el11.x*1E-6, el11.y*1E-6, el11.z*1E-6,lw=0.2, c= el11.Energy, cmap=plt.cm.gnuplot_r,label='Energy (GeV)')
#ax.plot(el.xx, el.yy, el.zz,'o')
fig.colorbar(surf, shrink=0.7, extend='min', label='Energy (MeV)')
#plt.title('Electrons Vertex')
ax.view_init(elev=0)
#ax.set_zlim(0,-200)


ax.set_xlabel('X (km)')
ax.set_ylabel('Y (km)')
ax.set_zlabel('Z (km)')
#plt.savefig('tp_3dcolormap.png')
# Out:
# <img src="data:image/png;base64,..." width="1140">
# Text(0.5,0,u'Z (km)')

# %%
np.sqrt(0.819**2 + (-0.574)**2)
# Out:
# 1.0001184929797069

# %%
a=6.96e5*0.0152632*1.15/2

# %%
200/(a*1e5)
# Out:
# 3.2742159241674826e-07

# %%
1/4.86e-10
# Out:
# 2057613168.7242799

# %%
r=(0.010*6.96e5)

# %%
np.pi*r
# Out:
# 21865.48486898496

# %%
2057613168.7242799/21865.48486898496
# Out:
# 94103.24907282965
