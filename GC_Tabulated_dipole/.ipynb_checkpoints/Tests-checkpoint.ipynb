# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = 'test.txt'
data = pd.read_csv(data, delim_whitespace=True, comment=':', names=['step', 'x', 'y', 'z', 'Energy', 'dE', 'StepLength', 'TrackLength', 'NextVolume', 'ProcessName'])

# %%
#data2 refers to one proton released at 0,0,2500 km using dipole table 100x100x100
data2 = 'test2.txt'
data2 = pd.read_csv(data2, delim_whitespace=True, comment=':', names=['step', 'x', 'y', 'z', 'Energy', 'dE', 'StepLength', 'TrackLength', 'NextVolume', 'ProcessName'])

# %%
#data2 refers to trackId=7 electron 
trackID7 = 'electron7.txt'
trackID7 = pd.read_csv(trackID7, delim_whitespace=True, comment=':', names=['step', 'x', 'y', 'z', 'Energy', 'dE', 'StepLength', 'TrackLength', 'NextVolume', 'ProcessName'])

# %%
#data10 refers to one proton released at 0,0,2500 km using dipole table 10x10x10
data10 = 'test10.txt'
data10 = pd.read_csv(data10, delim_whitespace=True, comment=':', names=['step', 'x', 'y', 'z', 'Energy', 'dE', 'StepLength', 'TrackLength', 'NextVolume', 'ProcessName'])

# %%
tesla = 'TESTTESLA.txt'
tesla = pd.read_csv(tesla, delim_whitespace=True, names=['step', 'x', 'y', 'z', 'Energy', 'dE', 'StepLength', 'TrackLength', 'NextVolume', 'ProcessName'])

# %%
tesla

# %%
fig3 = plt.figure()
plt.plot(data2.x*1E-6, data2.z*1E-6, markersize=1.5, label='xz', lw=0.1)

plt.xlabel('x [km]')
plt.ylabel('z [km]')
plt.legend(markerscale=5.0)
#plt.savefig('tp_xz.png')
#plt.plot(data.y, data.z, 'o', markersize=1.5, label='xy')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig10 = plt.figure()
plt.plot(data10.x*1E-6, data10.z*1E-6, markersize=1.5, label='xz', lw=0.1)

plt.xlabel('x [km]')
plt.ylabel('z [km]')
plt.legend(markerscale=5.0)
#plt.savefig('tp_xz.png')
#plt.plot(data.y, data.z, 'o', markersize=1.5, label='xy')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
y=np.linspace(0, -10000, 100)
z=np.linspace(0,0,100)

# %%
fig3 = plt.figure()
plt.plot(data2.y*1e-6, data2.z*1e-6, markersize=1.5, label='yz', lw=0.1)
plt.plot(y,z)
plt.xlabel('y [km]')
plt.ylabel('z [km]')
plt.legend(markerscale=5.0)
#plt.xlim(-1803,-1798)
#plt.savefig('tp_yz.png')
#plt.plot(data.y, data.z, 'o', markersize=1.5, label='xy')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig10 = plt.figure()
plt.plot(data10.y*1e-6, data10.z*1e-6, markersize=1.5, label='yz', lw=0.1)
plt.plot(y,z)
plt.xlabel('y [km]')
plt.ylabel('z [km]')
plt.legend(markerscale=5.0)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig3 = plt.figure()
plt.plot(data2.x*1e-6, data2.y*1e-6, markersize=1.5, label='xy', lw=0.1)


plt.xlabel('x [km]')
plt.ylabel('y [km]')
plt.legend(markerscale=5.0)
#plt.savefig('tp_xy.png')
#plt.plot(data.y, data.z, 'o', markersize=1.5, label='xy')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig10 = plt.figure()
plt.plot(data10.x*1e-6, data10.y*1e-6, markersize=1.5, label='xy', lw=0.1)


plt.xlabel('x [km]')
plt.ylabel('y [km]')
plt.legend(markerscale=5.0)
#plt.savefig('tp_xy.png')
#plt.plot(data.y, data.z, 'o', markersize=1.5, label='xy')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import matplotlib as mpl
from mpl_toolkits.mplot3d import Axes3D

# %%
fig = plt.figure(figsize=(12, 9), dpi=95)
ax = fig.add_subplot(111, projection='3d')
surf=ax.scatter3D(data2.x[1104342:1104627]*1E-6, data2.y[1104342:1104627]*1E-6, data2.z[1104342:1104627]*1E-6,lw=0.2, c= data2.Energy[1104342:1104627], cmap=plt.cm.gnuplot_r,label='Energy (GeV)')
#ax.plot(el.xx, el.yy, el.zz,'o')
fig.colorbar(surf, shrink=0.7, extend='min', label='Energy (MeV)')
#plt.title('Electrons Vertex')
ax.view_init(elev=0)
#ax.set_zlim(0,-200)


ax.set_xlabel('X (km)')
ax.set_ylabel('Y (km)')
ax.set_zlabel('Z (km)')
#plt.savefig('tp_3dcolormap.png')
# Out:
# <img src="data:image/png;base64,..." width="1140">
# Text(0.5,0,u'Z (km)')

# %%
fig = plt.figure(figsize=(12, 9), dpi=95)
ax = fig.add_subplot(111, projection='3d')
surf=ax.scatter3D(data10.x*1E-6, data10.y*1E-6, data10.z*1E-6,lw=0.2, c= data10.Energy, cmap=plt.cm.gnuplot_r,label='Energy (GeV)')
#ax.plot(el.xx, el.yy, el.zz,'o')
fig.colorbar(surf, shrink=0.7, extend='min', label='Energy (MeV)')
#plt.title('Electrons Vertex')
ax.view_init(elev=0)
#ax.set_zlim(0,-200)


ax.set_xlabel('X (km)')
ax.set_ylabel('Y (km)')
ax.set_zlabel('Z (km)')
#plt.savefig('tp_3dcolormap.png')
# Out:
# <img src="data:image/png;base64,..." width="1140">
# Text(0.5,0,u'Z (km)')

# %%
fig = plt.figure(figsize=(12, 9), dpi=95)
ax = fig.add_subplot(111, projection='3d')
surf=ax.plot3D(data10.x*1E-6, data10.y*1E-6, data10.z*1E-6,lw=0.4)#, c= data10.Energy, cmap=plt.cm.gnuplot_r,label='Energy (GeV)')
#ax.plot(el.xx, el.yy, el.zz,'o')
#fig.colorbar(surf, shrink=0.7, extend='min', label='Energy (MeV)')
#plt.title('Electrons Vertex')
ax.view_init(elev=0)
#ax.set_zlim(0,-200)


ax.set_xlabel('X (km)')
ax.set_ylabel('Y (km)')
ax.set_zlabel('Z (km)')
#plt.savefig('tp_3dcolormap.png')
# Out:
# <img src="data:image/png;base64,..." width="1140">
# Text(0.5,0,u'Z (km)')

# %%
fig3 = plt.figure()
plt.scatter(data2.x[1104342:1104627]*1E-6, data2.z[1104342:1104627]*1E-6,  label='xz', lw=1,c= data2.Energy[1104342:1104627])#, cmap=plt.cm.gnuplot_r,label='Energy (GeV)')
plt.colorbar()
plt.xlabel('x [km]')
plt.ylabel('z [km]')
plt.legend(markerscale=1.0)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig3 = plt.figure()
plt.scatter(data10.x*1E-6, data10.z*1E-6,  label='xz', lw=1,c= data10.Energy, linewidths=data.x*1E-6)#, cmap=plt.cm.gnuplot_r,label='Energy (GeV)')
plt.colorbar()
plt.xlabel('x [km]')
plt.ylabel('z [km]')
plt.legend(markerscale=1.0)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig3 = plt.figure()
plt.scatter(data2.y[1104342:1104627]*1E-6, data2.z[1104342:1104627]*1E-6,  label='yz', lw=1,c= data2.Energy[1104342:1104627])#, cmap=plt.cm.gnuplot_r,label='Energy (GeV)')
plt.colorbar()
plt.xlabel('y [km]')
plt.ylabel('z [km]')
plt.legend(markerscale=1.0)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig3 = plt.figure()
plt.scatter(data2.x[1104342:1104627]*1E-6, data2.y[1104342:1104627]*1E-6,  label='xy', lw=1,c= data2.Energy[1104342:1104627])#, cmap=plt.cm.gnuplot_r,label='Energy (GeV)')
plt.colorbar()
plt.xlabel('x [km]')
plt.ylabel('y [km]')
plt.legend(markerscale=1.0)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig3 = plt.figure()
plt.plot(data2.y[1104342:1104627]*1E-6, data2.z[1104342:1104627]*1E-6, markersize=1.5, label='yz', lw=1)

plt.xlabel('y [km]')
plt.ylabel('z [km]')
plt.legend(markerscale=5.0)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig3 = plt.figure()
plt.plot(data2.x[1104342:1104627]*1E-6, data2.y[1104342:1104627]*1E-6, markersize=1.5, label='xy', lw=1)

plt.xlabel('x [km]')
plt.ylabel('y [km]')
plt.legend(markerscale=5.0)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig3 = plt.figure()
plt.plot(data2.x[1104342:1104627]*1E-6, data2.z[1104342:1104627]*1E-6, markersize=1.5, label='xz', lw=1)

plt.xlabel('x [km]')
plt.ylabel('z [km]')
plt.legend(markerscale=5.0)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig = plt.figure(figsize=(12, 9), dpi=95)
ax = fig.add_subplot(111, projection='3d')
surf=ax.scatter(trackID7.x*1E-6, trackID7.y*1E-6, trackID7.z*1E-6,lw=0.2, c= trackID7.Energy, cmap=plt.cm.gnuplot_r,label='Energy (GeV)')
#ax.plot(el.xx, el.yy, el.zz,'o')
fig.colorbar(surf, shrink=0.7, extend='min', label='Energy (MeV)')
#plt.title('Electrons Vertex')
ax.view_init(elev=0)
#ax.set_zlim(0,-200)


ax.set_xlabel('X (km)')
ax.set_ylabel('Y (km)')
ax.set_zlabel('Z (km)')
#plt.savefig('tp_3d.png')
# Out:
# <img src="data:image/png;base64,..." width="1140">
# Text(0.5,0,u'Z (km)')

# %%
np.max(Bz)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-58-564066dcaa65> in <module>()
# ----> 1 np.max(Bz)
#
# NameError: name 'Bz' is not defined

# %%
fig = plt.figure()
Plot_gamma()
plt.savefig('Gamma_UniformMagField.pdf')
# Out:
# <img src="data:image/png;base64,..." width="900">
# nbins=  100 npr=  500000

# %%
figure2 = plt.figure()
Plot_positron()
#plt.step(positronflu.emax*1E3, positronflu.countpos2*1E-3, where='post', linewidth=0.4, label='$e^+ - Fluka$')
plt.legend()
#plt.savefig('PositronG4vsFluka-beamed10.pdf')
# Out:
# <img src="data:image/png;base64,..." width="900">
# nbins=  100 npr=  500000

# %%
len(el)/5000000.0, len(pos)/5000000.0, len(el)*1.0/len(pos)*1.0
# Out:
# (0.004544, 0.0028502, 1.5942740860290505)

# %%
0.004544/0.0028502
# Out:
# 1.5942740860290505

# %%
figure3 = plt.figure()
Plot_gamma()
#plt.step(gammaflu.emax*1E3, gammaflu.countg2*1E-3, where='pre', linewidth=0.4, label='$\gamma - Fluka$')
plt.legend()
#plt.savefig('PhotonsG4vsFluka-beamed10.pdf')
# Out:
# <img src="data:image/png;base64,..." width="900">
# nbins=  100 npr=  500000

# %%
xy = plt.figure()


Plot_neutron()
# Out:
# <img src="data:image/png;base64,..." width="900">
# nbins=  100 npr=  500000

# %%
figure2 = plt.figure()



plt.plot(el.x*1E-5, el.y*1E-5,'o', markersize=1.5, label='$e^-$')
plt.plot(pos.x*1E-5, pos.y*1E-5,'o', markersize=1.5, label='$e^+$')

#plt.plot(ElhIoni.x*1E-5, ElhIoni.y*1E-5, 'o', label='hIoni', markersize=1.5)
#plt.plot(Elcompton.x*1E-5, Elcompton.y*1E-5, 'o', label = 'compton', markersize=1.5)
#plt.plot(Elconv.x*1E-5, Elconv.y*1E-5, 'o', label = 'conv', markersize=1.5)
#plt.plot(EleIoni.x*1E-5, EleIoni.y*1E-5, 'o', label='eIoni', markersize=1.5)
#plt.plot(ElionIoni.x*1E-5, ElionIoni.y*1E-5, 'o', label='ionIoni', markersize=1.5)


#plt.plot(Posconv.x*1E-5, Posconv.y*1E-5, '*', label='e+ conv', markersize=1.0)
#plt.plot(PosDecay.x*1E-5, PosDecay.y*1E-5, '*', label='e+ Decay', markersize=1.0)

plt.xlabel('x [km]')
plt.ylabel('y [km]')
plt.legend(markerscale=5.0)
#plt.xlim(-0.25,0.25)
#plt.ylim(-0.25,0.25)
plt.savefig('Pos_El_UniformMagField2.png')
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
figure2 = plt.figure()



plt.plot(gamma.x*1E-5, gamma.y*1E-5,'o', markersize=1.5, label='$\gamma$')
#plt.plot(el.x*1E-5, el.y*1E-5,'o', markersize=1.5, label='$e^-$')
#plt.plot(pos.x*1E-5, pos.y*1E-5,'o', markersize=1.5, label='$e^+$')



#plt.plot(ElhIoni.x*1E-5, ElhIoni.y*1E-5, 'o', label='hIoni', markersize=1.5)
#plt.plot(Elcompton.x*1E-5, Elcompton.y*1E-5, 'o', label = 'compton', markersize=1.5)
#plt.plot(Elconv.x*1E-5, Elconv.y*1E-5, 'o', label = 'conv', markersize=1.5)
#plt.plot(EleIoni.x*1E-5, EleIoni.y*1E-5, 'o', label='eIoni', markersize=1.5)
#plt.plot(ElionIoni.x*1E-5, ElionIoni.y*1E-5, 'o', label='ionIoni', markersize=1.5)


#plt.plot(Posconv.x*1E-5, Posconv.y*1E-5, '*', label='e+ conv', markersize=1.0)
#plt.plot(PosDecay.x*1E-5, PosDecay.y*1E-5, '*', label='e+ Decay', markersize=1.0)

plt.xlabel('x [km]')
plt.ylabel('y [km]')
plt.legend(markerscale=5.0)
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
r0=(np.sqrt((el.x**2)+(el.y**2)))
r0hI=(np.sqrt((ElhIoni.x**2)+(ElhIoni.y**2)))
r0D=(np.sqrt((ElDecay.x**2)+(ElDecay.y**2)))
r0conv=(np.sqrt((Elconv.x**2)+(Elconv.y**2)))
r0comp=(np.sqrt((Elcompton.x**2)+(Elcompton.y**2)))
r0eI=(np.sqrt((EleIoni.x**2)+(EleIoni.y**2)))
r0iI=(np.sqrt((ElionIoni.x**2)+(ElionIoni.y**2)))

# %%
# Out:
# 9226

# %%
print 'ELECTRONS'
print 'mean radius compton [km] = ', np.mean(r0comp)*1E-5,'    ', 'max radius compton [km] = ', np.max(r0comp)*1E-5
print 'mean radius hIoni [km] = ', np.mean(r0hI)*1E-5,'     ', 'max radius hIoni [km] = ', np.max(r0hI)*1E-5
print 'mean radius conv [km] = ', np.mean(r0conv)*1E-5,'      ', 'max radius conv [km] = ', np.max(r0conv)*1E-5
print 'mean radius Decay [km] = ', np.mean(r0D)*1E-5,'     ', 'max radius Decay [km] = ', np.max(r0D)*1E-5
print 'mean radius eIoni [km] ', np.mean(r0eI)*1E-5,'      ', 'max radius eIoni [km] ', np.max(r0eI)*1E-5#, 'radius ionI [km]', np.mean(r0iI)*1E-
# Out:
# ELECTRONS
# mean radius compton [km] =  1.4194722967      max radius compton [km] =  18.2801410402
# mean radius hIoni [km] =  0.00207044993813       max radius hIoni [km] =  2.73402381403
# mean radius conv [km] =  1.52266044069        max radius conv [km] =  18.2227146704
# mean radius Decay [km] =  2.49881669576       max radius Decay [km] =  120.485771663
# mean radius eIoni [km]  2.01652285153        max radius eIoni [km]  115.401124771

# %%
r0posconv=(np.sqrt((Posconv.x**2)+(Posconv.y**2)))
r0posD=(np.sqrt((PosDecay.x**2)+(PosDecay.y**2)))

# %%
print 'POSITRONS'
print 'mean radius conv [km] = ', np.mean(r0posconv)*1E-5,'    ', 'max radius compton [km] = ', np.max(r0posconv)*1E-5
print 'mean radius Decay [km] = ', np.mean(r0posD)*1E-5,'     ', 'max radius Decay [km] = ', np.max(r0posD)*1E-5
# Out:
# POSITRONS
# mean radius conv [km] =  547.847273829      max radius compton [km] =  2826.33716382
# mean radius Decay [km] =  0.0518314321707       max radius Decay [km] =  0.111443341354

# %%
plot = plt.figure()
plt.plot(r0hI.reset_index(drop=True)*1E-5, 'o', label='hIoni', markersize=5)
plt.plot(r0comp.reset_index(drop=True)*1E-5, 'o', label='compton', markersize=5)
plt.plot(r0conv.reset_index(drop=True)*1E-5, 'o', label='conv', markersize=5)
plt.plot(r0eI.reset_index(drop=True)*1E-5, 'o', label='eIoni', markersize=5)
plt.plot(r0D.reset_index(drop=True)*1E-5, 'o', label='Decay', markersize=5)

#plt.yscale('log')
plt.xlabel('index (events)')
plt.ylabel('radius [km]')



plt.legend(loc=4)
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
# %matplotlib nbagg
fig = plt.figure(figsize=(9,9))



ax1 = fig.add_subplot(331)
ax2 = fig.add_subplot(332)
ax3 = fig.add_subplot(333)
ax4 = fig.add_subplot(334)
ax5 = fig.add_subplot(335)
ax6 = fig.add_subplot(337)
ax7 = fig.add_subplot(338)

ax1.plot(r0conv.reset_index(drop=True)*1E-5, 'o', label='conv',color='k', markersize=0.9)


ax2.plot(r0comp.reset_index(drop=True)*1E-5, 'o', label='compton', color='k', markersize=0.9)


ax3.plot(r0D.reset_index(drop=True)*1E-5, 'o', label='Decay', color='k', markersize=0.9)


ax4.plot(r0hI.reset_index(drop=True)*1E-5, 'o', label='hIoni', color='k', markersize=0.9)


ax5.plot(r0eI.reset_index(drop=True)*1E-5, 'o', label='eIoni', color='k', markersize=0.9)

ax6.plot(r0posD.reset_index(drop=True)*1E-5, 'o', label='Decay',  markersize=0.9)

ax7.plot(r0posconv.reset_index(drop=True)*1E-5, 'o', label='conv', markersize=0.9)


ax1.legend()
ax2.legend()
ax3.legend()
ax4.legend()
ax5.legend()
ax6.legend()
ax7.legend()

ax1.set_ylabel('Radius [km]')
ax4.set_ylabel('Radius [km]')
ax6.set_ylabel('Radius [km]')

ax3.set_xlabel('Index (events)')
ax6.set_xlabel('Index (events)')
ax7.set_xlabel('Index (events)')
# Out:
# <img src="data:image/png;base64,..." width="900">
# Text(0.5,0,u'Index (events)')

# %%
import matplotlib as mpl
from mpl_toolkits.mplot3d import Axes3D

# %%
fig = plt.figure(figsize=(12, 9), dpi=95)
ax = fig.add_subplot(111, projection='3d')
surf=ax.scatter(el.Vx*1E-5, el.Vy*1E-5, el.Vz*1E-5,'o', c= el.Ekin, cmap=plt.cm.gnuplot_r,label='Energy (GeV)')
#ax.plot(el.xx, el.yy, el.zz,'o')
fig.colorbar(surf, shrink=0.7, extend='min', label='Energy (MeV)')
plt.title('Electrons Vertex')
ax.view_init(elev=0)
ax.set_zlim(-6,2)


ax.set_xlabel('X (km)')
ax.set_ylabel('Y (km)')
ax.set_zlabel('Z (km)')
# Out:
# <img src="data:image/png;base64,..." width="1140">
# Text(0.5,0,u'Z (km)')

# %%
fig = plt.figure(figsize=(12, 9), dpi=80)
ax = fig.add_subplot(111, projection='3d')
ax.scatter(ElhIoni.Vx*1E-5, ElhIoni.Vy*1E-5, ElhIoni.Vz*1E-5,'o', label='hIoni')
ax.scatter(Elcompton.Vx*1E-5, Elcompton.Vy*1E-5, Elcompton.Vz*1E-5,'o', label='compton')
ax.scatter(Elconv.Vx*1E-5, Elconv.Vy*1E-5, Elconv.Vz*1E-5,'o', label='conv')
ax.scatter(EleIoni.Vx*1E-5, EleIoni.Vy*1E-5, EleIoni.Vz*1E-5,'o', label='eIoni')
ax.scatter(ElDecay.Vx*1E-5, ElDecay.Vy*1E-5, ElDecay.Vz*1E-5,'o', label='Decay')
ax.view_init(elev=0)

ax.set_zlim(-6, 2)
plt.legend(scatterpoints=3)


#ax.plot(el.xx, el.yy, el.zz,'o')
#fig.colorbar(surf, shrink=0.7, extend='min')
plt.title('Electrons by process Vertex')
ax.set_xlabel('X (km)')
ax.set_ylabel('Y (km)')
ax.set_zlabel('Z (km)')
# Out:
# <img src="data:image/png;base64,..." width="960">
# Text(0.5,0,u'Z (km)')

# %%
fig = plt.figure(figsize=(12, 9), dpi=80)
ax = fig.add_subplot(111, projection='3d')
surf=ax.scatter(pos.Vx*1E-5, pos.Vy*1E-5, pos.Vz*1E-5,'o', c= pos.Ekin, cmap=plt.cm.gnuplot_r,label='Energy (GeV)')
#ax.plot(el.xx, el.yy, el.zz,'o')
fig.colorbar(surf, shrink=0.7, extend='min', label='Energy (MeV)')
plt.title('Positrons Vertex')
ax.view_init(elev=0)

ax.set_xlabel('X (km)')
ax.set_ylabel('Y (km)')
ax.set_zlabel('Z (km)')
# Out:
# <img src="data:image/png;base64,..." width="960">
# Text(0.5,0,u'Z (km)')

# %%
fig = plt.figure(figsize=(12, 9), dpi=80)
ax = fig.add_subplot(111, projection='3d')
#ax.scatter(ElhIoni.Vx*1E-5, ElhIoni.Vy*1E-5, ElhIoni.Vz*1E-5,'o', label='hIoni')
#ax.scatter(Elcompton.Vx*1E-5, Elcompton.Vy*1E-5, Elcompton.Vz*1E-5,'o', label='compton')
ax.scatter(Posconv.Vx*1E-5, Posconv.Vy*1E-5, Posconv.Vz*1E-5,'o', label='conv')
#ax.scatter(EleIoni.Vx*1E-5, EleIoni.Vy*1E-5, EleIoni.Vz*1E-5,'o', label='eIoni')
ax.scatter(PosDecay.Vx*1E-5, PosDecay.Vy*1E-5, PosDecay.Vz*1E-5,'o', label='Decay', alpha=0.4)

plt.legend(scatterpoints=3)
ax.view_init(elev=0)



#ax.plot(el.xx, el.yy, el.zz,'o')
#fig.colorbar(surf, shrink=0.7, extend='min')
plt.title('Positrons by process Vertex')
ax.set_xlabel('X (km)')
ax.set_ylabel('Y (km)')
ax.set_zlabel('Z (km)')
# Out:
# <img src="data:image/png;base64,..." width="960">
# Text(0.5,0,u'Z (km)')

# %%
fig = plt.figure(figsize=(12, 9), dpi=80)
ax = fig.add_subplot(111, projection='3d')
surf=ax.scatter(gamma.Vx*1E-5, gamma.Vy*1E-5, gamma.Vz*1E-5,'o', c= gamma.Ekin, cmap=plt.cm.gnuplot_r,label='Energy (GeV)')
#ax.plot(el.xx, el.yy, el.zz,'o')
fig.colorbar(surf, shrink=0.7, extend='min', label='Energy (MeV)')
plt.title('Gamma Vertex')
ax.view_init(elev=0)

ax.set_xlabel('X (km)')
ax.set_ylabel('Y (km)')
ax.set_zlabel('Z (km)')
# Out:
# <img src="data:image/png;base64,..." width="960">
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-f4b647b1698b> in <module>()
#       1 fig = plt.figure(figsize=(12, 9), dpi=80)
#       2 ax = fig.add_subplot(111, projection='3d')
# ----> 3 surf=ax.scatter(gamma.Vx*1E-5, gamma.Vy*1E-5, gamma.Vz*1E-5,'o', c= gamma.Ekin, cmap=plt.cm.gnuplot_r,label='Energy (GeV)')
#       4 #ax.plot(el.xx, el.yy, el.zz,'o')
#       5 fig.colorbar(surf, shrink=0.7, extend='min', label='Energy (MeV)')
#
# /home/jordi/anaconda2/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    3079             if name in self._info_axis:
#    3080                 return self[name]
# -> 3081             return object.__getattribute__(self, name)
#    3082
#    3083     def __setattr__(self, name, value):
#
# ...

# %%
gamma
# Out:
#         emin      emax     countg2    erro
# 0        NaN       NaN         NaN     NaN
# 1        NaN       NaN         NaN     NaN
# 2   0.000100  0.000112  193.400000   2.084
# 3   0.000112  0.000126  165.400000   2.418
# 4   0.000126  0.000141  145.700000   2.439
# 5   0.000141  0.000159  121.800000   2.156
# 6   0.000159  0.000178  103.100000   1.959
# 7   0.000178  0.000199   88.390000   2.035
# 8   0.000199  0.000224   77.380000   2.270
# 9   0.000224  0.000251   65.350000   2.449
# 10  0.000251  0.000282   58.600000   2.021
# 11  0.000282  0.000316   52.720000   1.795
# 12  0.000316  0.000355   44.290000   2.068
# 13  0.000355  0.000398   38.990000   2.779
# 14  0.000398  0.000447   37.260000   2.159
# 15  0.000447  0.000501   33.060000   2.733
# 16  0.000501  0.000562   75.090000   1.457
# 17  0.000562  0.000631   13.190000   4.008
# 18  0.000631  0.000708   11.730000   3.451
# 19  0.000708  0.000794    9.516000   3.307
# 20  0.000794  0.000891    8.894000   3.649
# ...

# %%
fig = plt.figure(figsize=(12, 9), dpi=80)
ax = fig.add_subplot(111, projection='3d')

ax.scatter(pos.x[46]*1E-5, pos.y[46]*1E-5, pos.z[46]*1E-5, label='$e^-$')
ax.scatter(pos.Vx[46]*1E-5, pos.Vy[46]*1E-5, pos.Vz[46]*1E-5, label='$e^- Vertex$')

ax.view_init(elev=0)


plt.legend(scatterpoints=3)

#ax.set_xlim(-5000, 5000)
#ax.set_ylim(-5000, 5000)
#ax.set_zlim(-5000, 5000)



#ax.plot(el.xx, el.yy, el.zz,'o')
#fig.colorbar(surf, shrink=0.7, extend='min')
#plt.title('Electrons conv')
ax.set_xlabel('X (km)')
ax.set_ylabel('Y (km)')
ax.set_zlabel('Z (km)')
#plt.savefig('localPositionXY3d.pdf')
# Out:
# <img src="data:image/png;base64,..." width="960">
# Text(0.5,0,u'Z (km)')

# %%
Processes('gamma')
# Out:
# ['eBrem' 'annihil' 'neutronInelastic' 'protonInelastic' 'Decay' 'nCapture'
#  'He3Inelastic' 'tInelastic']

# %%
fig6 = plt.figure(figsize=(9,6))
#ax = fig.add_subplot(111, projection='3d')
x=pos.x*1E-5
y=pos.y*1E-5

u=pos.Mx*1E-5
v=pos.My*1E-5

#xx=Posconv.Vx
#yy=Posconv.Vy

#uu=Posconv.VMx
#vv=Posconv.VMy




plt.quiver(x,y,u,v)
a=plt.scatter(pos.x*1E-5, pos.y*1E-5)
#plt.savefig('localPositionXYVector.pdf')
plt.title('Positrons direction')
plt.xlabel('X [km]')
plt.ylabel('Y [km]')
#plt.quiver(xx,yy,uu,vv)
#b=plt.scatter(Posconv.Vx, Posconv.Vy)
#fig6.colorbar(a,shrink=1.0, label='Energy (GeV)', extend='min')
#plt.title('Pos-El from Dalitz decay (Position, Energy, Direction)')
# Out:
# <img src="data:image/png;base64,..." width="900">
# Text(0,0.5,u'Y [km]')

# %%
fig6 = plt.figure(figsize=(9,6))
#ax = fig.add_subplot(111, projection='3d')
x=el.x*1E-5
y=el.y*1E-5

u=el.Mx*1E-5
v=el.My*1E-5

#xx=Posconv.Vx
#yy=Posconv.Vy

#uu=Posconv.VMx
#vv=Posconv.VMy




plt.quiver(x,y,u,v)
a=plt.scatter(el.x*1E-5, el.y*1E-5)
#plt.savefig('localPositionXYVector.pdf')
plt.title('Electrons direction')
plt.xlabel('X [km]')
plt.ylabel('Y [km]')
#plt.quiver(xx,yy,uu,vv)
#b=plt.scatter(Posconv.Vx, Posconv.Vy)
#fig6.colorbar(a,shrink=1.0, label='Energy (GeV)', extend='min')
#plt.title('Pos-El from Dalitz decay (Position, Energy, Direction)')
# Out:
# <img src="data:image/png;base64,..." width="900">
# Text(0,0.5,u'Y [km]')

# %%
Processes('gamma')
# Out:
# ['eBrem' 'annihil' 'Decay' 'nCapture' 'protonInelastic' 'pi+Inelastic'
#  'neutronInelastic' 'dInelastic' 'photonNuclear' 'tInelastic'
#  'He3Inelastic' 'muMinusCaptureAtRest' 'pi-Inelastic' 'electronNuclear'
#  'hBrems' 'hBertiniCaptureAtRest']

# %% [markdown]
# fig = plt.figure()
# Plot_neutron_all()

# %%
pwd
# Out:
# u'/home/jordi/g4work/_1glasgow/Chord_Parameters(F04)/build/analysis'

# %%
np.sqrt((0.00002856**2)+(0.00010215**2)+(0.00004101**2))
# Out:
# 0.00011371946271417221

# %%
0.00011371946271417221*10000
# Out:
# 1.1371946271417221
